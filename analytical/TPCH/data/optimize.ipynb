# %%
# %%sql
# create schema if not exists OP1000
# Out:
# StatementMeta(, 5a97dd3b-d047-426b-b183-f3f220d8e2f1, 4, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
for x in ['lineitem','customer','nation','orders','part','partsupp','supplier','region'] :
 spark.sql(f" create table OP1000.{x} as select * from CH1000.{x}  ")
# Out:
# StatementMeta(, 5a97dd3b-d047-426b-b183-f3f220d8e2f1, 7, Finished, Available, Finished)
